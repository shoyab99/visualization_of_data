# %%
#data visualization is a graphical representation of data such as charts,graphs....
#matplotlib  and seaborn are the libraries that visualize the data
import matplotlib
import seaborn
print(f"...The functions of seaborn are :{seaborn.__dir__()}") #print all functions of seaborn
print(f"\n.....The functions of matplotlib are :{matplotlib.__dir__()}") #printing all the functions of matplotlib
# Out:
# ...The functions of seaborn are :['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__path__', '__file__', '__cached__', '__builtins__', 'external', 'utils', 'colors', 'palettes', 'rcmod', 'set_theme', 'set', 'reset_defaults', 'reset_orig', 'axes_style', 'set_style', 'plotting_context', 'set_context', 'set_palette', 'desaturate', 'saturate', 'set_hls_values', 'move_legend', 'despine', 'get_dataset_names', 'get_data_home', 'load_dataset', 'color_palette', 'hls_palette', 'husl_palette', 'mpl_palette', 'dark_palette', 'light_palette', 'diverging_palette', 'blend_palette', 'xkcd_palette', 'crayon_palette', 'cubehelix_palette', 'set_color_codes', '_decorators', '_core', 'algorithms', '_docstrings', 'axisgrid', 'relational', 'relplot', 'scatterplot', 'lineplot', 'regression', 'lmplot', 'regplot', 'residplot', 'categorical', 'catplot', 'factorplot', 'stripplot', 'swarmplot', 'boxplot', 'violinplot', 'boxenplot', 'pointplot', 'barplot', 'countplot', '_statistics', 'distributio
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#1.load the data
df=pd.read_csv("most_runs_came_from_boundry_in_an_innings.csv")

# %%
df.head() #head() returns the first n rows of the data
# Out:
#          Player  Runs  Mins  Balls  4s  6s  4+6      SR          Team  \
# 0    GJ Maxwell   201   181    128  21  10  144  157.03     Australia
# 1      MR Marsh   177   177    132  17   9  122  134.09     Australia
# 2     DA Warner   163   180    124  14   9  110  131.45     Australia
# 3     Q de Kock   174   192    140  15   7  102  124.28  South Africa
# 4  Fakhar Zaman   126   103     81   8  11   98  155.55      Pakistan
#
#       Opposition     Ground   Match Date   Scorecard
# 0  v Afghanistan   Wankhede  07 Nov 2023  ODI # 4696
# 1   v Bangladesh       Pune  11 Nov 2023  ODI # 4700
# 2     v Pakistan  Bengaluru  20 Oct 2023  ODI # 4675
# 3   v Bangladesh   Wankhede  24 Oct 2023  ODI # 4680
# 4  v New Zealand  Bengaluru  04 Nov 2023  ODI # 4692

# %%
df.tail() #tail() returns last n rows ot the data
# Out:
#              Player  Runs  Mins  Balls  4s 6s  4+6      SR         Team  \
# 95     BFW de Leede    67    92     68   6  2   36   98.52  Netherlands
# 96  Mushfiqur Rahim    66    93     75   6  2   36   88.00   Bangladesh
# 97         MR Marsh    52    67     51   9  -   36  101.96    Australia
# 98       P Nissanka    54    69     52   9  -   36  103.84    Sri Lanka
# 99        MP O'Dowd    42    50     40   9  -   36  105.00  Netherlands
#
#        Opposition     Ground   Match Date   Scorecard
# 95     v Pakistan  Hyderabad  06 Oct 2023  ODI # 4659
# 96  v New Zealand    Chennai  13 Oct 2023  ODI # 4668
# 97    v Sri Lanka    Lucknow  16 Oct 2023  ODI # 4671
# 98  v Netherlands    Lucknow  21 Oct 2023  ODI # 4676
# 99  v Afghanistan    Lucknow  03 Nov 2023  ODI # 4691

# %%
df.sample(4) #returns random data
# Out:
#           Player  Runs  Mins  Balls  4s 6s  4+6      SR          Team  \
# 55      M Jansen    75    72     42   3  6   48  178.57  South Africa
# 62    SA Edwards    78   102     69  10  1   46  113.04   Netherlands
# 54       V Kohli   103   113     97   6  4   48  106.18         India
# 95  BFW de Leede    67    92     68   6  2   36   98.52   Netherlands
#
#         Opposition      Ground   Match Date   Scorecard
# 55       v England    Wankhede  21 Oct 2023  ODI # 4677
# 62  v South Africa  Dharamsala  17 Oct 2023  ODI # 4672
# 54    v Bangladesh        Pune  19 Oct 2023  ODI # 4674
# 95      v Pakistan   Hyderabad  06 Oct 2023  ODI # 4659

# %%
df['Ground'].value_counts() #prints frequency of occurance in the column
# Out:
# Wankhede        18
# Delhi           16
# Bengaluru       13
# Pune            10
# Dharamsala      10
# Chennai          8
# Hyderabad        7
# Eden Gardens     7
# Lucknow          6
# Ahmedabad        5
# Name: Ground, dtype: int64

# %%
df['4s'].value_counts()
# Out:
# 9     16
# 8     15
# 10    12
# 7      9
# 6      9
# 11     8
# 4      6
# 12     5
# 14     3
# 15     3
# 3      3
# 2      2
# 16     2
# 5      2
# 21     1
# 13     1
# 17     1
# 19     1
# 1      1
# Name: 4s, dtype: int64

# %%
df.dtypes
# Out:
# Player         object
# Runs            int64
# Mins            int64
# Balls           int64
# 4s              int64
# 6s             object
# 4+6             int64
# SR            float64
# Team           object
# Opposition     object
# Ground         object
# Match Date     object
# Scorecard      object
# dtype: object

# %%
df.duplicated() #print whether it has duplicate vales
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df.shape
# Out:
# (100, 13)

# %%
df.info() #prints information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      100 non-null    object
#  1   Runs        100 non-null    int64
#  2   Mins        100 non-null    int64
#  3   Balls       100 non-null    int64
#  4   4s          100 non-null    int64
#  5   6s          100 non-null    object
#  6   4+6         100 non-null    int64
#  7   SR          100 non-null    float64
#  8   Team        100 non-null    object
#  9   Opposition  100 non-null    object
#  10  Ground      100 non-null    object
#  11  Match Date  100 non-null    object
#  12  Scorecard   100 non-null    object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 10.3+ KB

# %%
df.describe(include="all") #prints descripiton of the data such as mean,medium,count,frequnecy
# Out:
#            Player        Runs        Mins       Balls          4s   6s  \
# count         100  100.000000  100.000000  100.000000  100.000000  100
# unique         53         NaN         NaN         NaN         NaN   12
# top     RG Sharma         NaN         NaN         NaN         NaN    2
# freq            7         NaN         NaN         NaN         NaN   23
# mean          NaN   93.230000  117.710000   80.750000    8.860000  NaN
# std           NaN   30.499497   42.106238   27.954283    3.590166  NaN
# min           NaN   42.000000   25.000000   17.000000    1.000000  NaN
# 25%           NaN   71.000000   87.000000   62.750000    7.000000  NaN
# 50%           NaN   87.500000  111.000000   78.000000    9.000000  NaN
# 75%           NaN  109.000000  149.250000  104.250000   10.250000  NaN
# max           NaN  201.000000  217.000000  143.000000   21.000000  NaN
#
#                4+6          SR   Team     Opposition    Ground   Match Date  \
# ...

# %%
#2.clean your data...
'''1.Removing unnecessary variables
2.Deleting duplicate rows/observations
3.Addressing outliers or invalid data
4.Dealing with missing values
5.Standardizing or categorizing values
6.Correcting typographical errors'''
# Out:
# '1.Removing unnecessary variables\n2.Deleting duplicate rows/observations\n3.Addressing outliers or invalid data\n4.Dealing with missing values\n5.Standardizing or categorizing values\n6.Correcting typographical errors'

# %%
#handle the missiing vlaues
df.isnull().sum()
# Out:
# Player        0
# Runs          0
# Mins          0
# Balls         0
# 4s            0
# 6s            0
# 4+6           0
# SR            0
# Team          0
# Opposition    0
# Ground        0
# Match Date    0
# Scorecard     0
# dtype: int64

# %%
#Line Chart
#Line Chart is used to represent a relationship between two data X and Y on a different axis.
#It is plotted using the plot() function. Let’s see the below example.
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.title("line chart") #naming the graph
plt.plot(xpoints, ypoints,color="green",marker='o',linestyle="solid") #linestyle can be solid dashed dotted..
#naming the x_axis and y_axis
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.grid() #grid lines
plt.show()

# %%
#Creating Bars -->A bar plot is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. 
#It can be created using the bar() method.
plt.title("bar chart")
plt.bar(df["Runs"],df['Mins'],width=2,color=['r','b','g'],linestyle='solid')
plt.xlabel("Runs")
plt.ylabel("Mins")
plt.show()

# %%
plt.bar(df["Balls"],df["Runs"])
plt.ylabel("Runs")
plt.xlabel("balls")
plt.show()

# %%
#Scatter Plot are used to observe relationships between variables and uses dots to represent the relationship between them.
#The scatter() method in the matplotlib library is used to draw a scatter plot.
plt.scatter(df['6s'],df['Team'],df["Runs"], marker='1',color=['g'],)
plt.title("six vs team")
plt.xlabel("sixes")
plt.ylabel("team")
plt.show()

# %%
#Histogram is basically used to represent data in the form of some groups.
#It is a type of bar plot where the X-axis represents the bin ranges while the Y-axis gives information about frequency. 
#The hist() function is used to compute and create a histogram.
# if we pass categorical data then it will automatically compute the frequency of that data i.e. how often each value occurred.
plt.hist(df['6s'])
plt.show()

# %%
plt.hist(df["Player"])
plt.show()

# %%
#pie chart is used to represnt the data in the form of percentage
#pie() method is used to create pie chart
plt.pie(df["Balls"])
plt.show()

# %%
#A bar plot gives an estimate of the central tendency for a numeric variable with the height of each rectangle. 
#It provides some indication of the uncertainty around that estimate using error bars. 
#To build this plot, you usually choose a categorical column on the x-axis and a numerical column on the y-axis.
#using seaborns
sns.barplot(x="Ground",y="Balls",data=df)
plt.show()

# %%
#The countplot() function in the Python Seaborn library returns the count of total values for each category using bars
sns.countplot(x="4s",data=df)
plt.show()

# %%
#Heatmaps in the Seaborn library lets you visualize matrix-like data. 
#The values of the variables are contained in a matrix and are represented as colors.
sns.heatmap(df.corr(),annot=True,linewidth=0.5)
plt.show()

# %%
#Pairplot is the Python Seaborn library lets you visualize data using pair plots that produce a matrix of relationships between each variable in the dataset.
sns.pairplot(df,hue="Balls")
